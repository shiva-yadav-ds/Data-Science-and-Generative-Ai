# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv', sep=',')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId', axis=1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index('Name', inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d = {'key1': [4, 3, 5, 6, 3],
     'key2': [1, 2, 3, 4, 5],
     'key3': [2, 3, 4, 5, 6]
     }

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     4     1     2
# 1     3     2     3
# 2     5     3     4
# 3     6     4     5
# 4     3     5     6

# %%
# Ames Housing dataset (with NaNs) from open repo
url = "https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv"

# Read dataset
df1 = pd.read_csv(url)

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df1.fillna("Shiva", inplace=True)

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2                             Heikkinen, Miss. Laina         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# ...

# %%
g = df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
#            index                                               Name  Pclass  \
# Survived
# 0         244315  Braund, Mr. Owen HarrisAllen, Mr. William Henr...    1390
# 1         151290  Cumings, Mrs. John Bradley (Florence Briggs Th...     666
#
#                                                         Sex       Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalefemalemalefemalema...  12985.50    304
# 1         femalefemalefemalefemalefemalefemalefemalemale...   8184.67    161
#
#           Parch                                             Ticket  \
# Survived
# 0           181  A/5 2117137345033087717463349909A/5. 215134708...
# 1           159  PC 17599STON/O2. 3101282347742237736PP 9549113...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# 1         16498.1294  C85G6C103D56A6B78D33C52B28F33C23 C25 C27D10 D1...
#
# ...

# %%
g1 = df.groupby(['Survived', 'Sex'])

# %%
g1.sum()
# Out:
#                   index                                               Name  \
# Survived Sex
# 0        female   35061  Vestrom, Miss. Hulda Amanda AdolfinaVander Pla...
#          male    209254  Braund, Mr. Owen HarrisAllen, Mr. William Henr...
# 1        female   99654  Cumings, Mrs. John Bradley (Florence Briggs Th...
#          male     51636  Williams, Mr. Charles EugeneBeesley, Mr. Lawre...
#
#                  Pclass       Age  SibSp  Parch  \
# Survived Sex
# 0        female     231   1603.00     98     84
#          male      1159  11382.50    206     97
# 1        female     446   5648.00    119    120
#          male       220   2536.67     42     39
#
#                                                             Ticket  \
# Survived Sex
# 0        female  350406345763349909345764754611668349237CA 2144...
#          male    A/5 2117137345033087717463349909A/5. 215134708...
# 1        female  PC 17599STON/O2. 3101282347742237736PP 9549113...
# ...

# %%
g2 = df.groupby('Pclass')

# %%
g2.sum(numeric_only=True)
# Out:
#          index  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1        99272       135  7076.42     89     77  18124.3125
# 2        81688        87  5168.83     74     70   3801.8417
# 3       214645       119  8924.92    302    193   6714.6951

# %%
g2.mean(numeric_only=True)
# Out:
#              index  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       461.730233  0.627907  38.250919  0.413953  0.358140  84.299128
# 2       443.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3       437.158859  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g2.max(numeric_only=True)
# Out:
#         index  Survived   Age  SibSp  Parch      Fare
# Pclass
# 1         888         1  80.0      3      4  512.3292
# 2         885         1  70.0      3      3   73.5000
# 3         889         1  74.0      8      6   69.5500

# %%
# Group the DataFrame and calculate the mean for numeric columns
g2 = df.groupby('Pclass')
g2.mean(numeric_only=True)
# Out:
#              index  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       461.730233  0.627907  38.250919  0.413953  0.358140  84.299128
# 2       443.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3       437.158859  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
for pclass, group_df in g2:
    print(f"Class: {pclass}")
    display(group_df['Name'].head())
# Out:
# Class: 1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 5                               McCarthy, Mr. Timothy J
# 10                             Bonnell, Miss. Elizabeth
# 22                         Sloper, Mr. William Thompson
# 26                       Fortune, Mr. Charles Alexander
# Name: Name, dtype: object
# Class: 2
# 8     Nasser, Mrs. Nicholas (Adele Achem)
# 14       Hewlett, Mrs. (Mary D Kingcome)
# 16           Williams, Mr. Charles Eugene
# 19                   Fynney, Mr. Joseph J
# 20                  Beesley, Mr. Lawrence
# Name: Name, dtype: object
# Class: 3
# 0           Braund, Mr. Owen Harris
# 2            Heikkinen, Miss. Laina
# 3          Allen, Mr. William Henry
# 4                  Moran, Mr. James
# 6    Palsson, Master. Gosta Leonard
# Name: Name, dtype: object

# %%
g2.max(numeric_only=True)
# Out:
#         index  Survived   Age  SibSp  Parch      Fare
# Pclass
# 1         888         1  80.0      3      4  512.3292
# 2         885         1  70.0      3      3   73.5000
# 3         889         1  74.0      8      6   69.5500

# %%
g2.max(numeric_only=True)['Age']
# Out:
# Pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: Age, dtype: float64

# %%
g2.max(numeric_only=True)['Age']
# Out:
# Pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: Age, dtype: float64

# %%
df5 = df[['Name', 'Age']][0:10]

# %%
df6 = df[['Name', 'Age']][20:35]

# %%
pd.concat([df5, df6])
# Out:
#                                                  Name   Age
# 0                             Braund, Mr. Owen Harris  22.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss. Laina  26.0
# 3                            Allen, Mr. William Henry  35.0
# 4                                    Moran, Mr. James   NaN
# 5                             McCarthy, Mr. Timothy J  54.0
# 6                      Palsson, Master. Gosta Leonard   2.0
# 7   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 8                 Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 9                     Sandstrom, Miss. Marguerite Rut   4.0
# 20                              Beesley, Mr. Lawrence  34.0
# 21                        McGowan, Miss. Anna "Annie"  15.0
# 22                       Sloper, Mr. William Thompson  28.0
# 23                      Palsson, Miss. Torborg Danira   8.0
# 24  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  38.0
# ...

# %%
pd.concat([df5, df6], axis=1)
# Out:
#                                                  Name   Age  \
# 0                             Braund, Mr. Owen Harris  22.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss. Laina  26.0
# 3                            Allen, Mr. William Henry  35.0
# 4                                    Moran, Mr. James   NaN
# 5                             McCarthy, Mr. Timothy J  54.0
# 6                      Palsson, Master. Gosta Leonard   2.0
# 7   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 8                 Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 9                     Sandstrom, Miss. Marguerite Rut   4.0
# 20                                                NaN   NaN
# 21                                                NaN   NaN
# 22                                                NaN   NaN
# 23                                                NaN   NaN
# 24                                                NaN   NaN
# ...

# %%
fill_nan = pd.concat([df5, df6], axis=1)

# %%
fill_nan.fillna(0, inplace=True)

# %%
fill_nan
# Out:
#                                                  Name   Age  \
# 0                             Braund, Mr. Owen Harris  22.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss. Laina  26.0
# 3                            Allen, Mr. William Henry  35.0
# 4                                    Moran, Mr. James   0.0
# 5                             McCarthy, Mr. Timothy J  54.0
# 6                      Palsson, Master. Gosta Leonard   2.0
# 7   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 8                 Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 9                     Sandstrom, Miss. Marguerite Rut   4.0
# 20                                                  0   0.0
# 21                                                  0   0.0
# 22                                                  0   0.0
# 23                                                  0   0.0
# 24                                                  0   0.0
# ...

# %%
m1 = {'key1': [4, 3, 5, 6, 3],
     'key2': [1, 2, 3, 4, 5],
     'key3': [2, 3, 4, 5, 6]
     }

# %%
m2 = {'key1': [4, 3, 5, 6, 3],
     'key4': [1, 2, 5, 53, 7],
     'key5': [2, 76, 4, 97, 4]
     }

# %%
df_m1 = pd.DataFrame(m1)
df_m2 = pd.DataFrame(m2)
pd.merge(df_m1, df_m2)
# Out:
#    key1  key2  key3  key4  key5
# 0     4     1     2     1     2
# 1     3     2     3     2    76
# 2     3     2     3     7     4
# 3     5     3     4     5     4
# 4     6     4     5    53    97
# 5     3     5     6     2    76
# 6     3     5     6     7     4

# %%
pd.merge(df_m1, df_m2, how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     3     2     3     2    76
# 1     3     2     3     7     4
# 2     3     5     6     2    76
# 3     3     5     6     7     4
# 4     4     1     2     1     2
# 5     5     3     4     5     4
# 6     6     4     5    53    97

# %%
pd.merge(df_m1, df_m2, how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     4     1     2     1     2
# 1     3     2     3     2    76
# 2     3     2     3     7     4
# 3     5     3     4     5     4
# 4     6     4     5    53    97
# 5     3     5     6     2    76
# 6     3     5     6     7     4

# %%
pd.merge(df_m1, df_m2, how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     4     1     2     1     2
# 1     3     2     3     2    76
# 2     3     5     6     2    76
# 3     5     3     4     5     4
# 4     6     4     5    53    97
# 5     3     2     3     7     4
# 6     3     5     6     7     4

# %%
pd.merge(df_m1, df_m2, how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        4     1     2       4     1     2
# 1        4     1     2       3     2    76
# 2        4     1     2       5     5     4
# 3        4     1     2       6    53    97
# 4        4     1     2       3     7     4
# 5        3     2     3       4     1     2
# 6        3     2     3       3     2    76
# 7        3     2     3       5     5     4
# 8        3     2     3       6    53    97
# 9        3     2     3       3     7     4
# 10       5     3     4       4     1     2
# 11       5     3     4       3     2    76
# 12       5     3     4       5     5     4
# 13       5     3     4       6    53    97
# 14       5     3     4       3     7     4
# 15       6     4     5       4     1     2
# 16       6     4     5       3     2    76
# 17       6     4     5       5     5     4
# 18       6     4     5       6    53    97
# 19       6     4     5       3     7     4
# 20       3     5     6       4     1     2
# ...

# %%
m1 = pd.DataFrame({'key1': [4, 3, 5, 6, 3],
     'key2': [1, 2, 3, 4, 5],
     'key3': [2, 3, 4, 5, 6]
}, index=['f', 'g', 'h', 'i', 'j']
)

# %%
m2 = pd.DataFrame({'key4': [4, 3, 5, 6, 3],
     'key5': [1, 0, 3, 4, 0],
     'key6': [2, 9, 2, 5, 5]
}, index=['f', 'g', 'h', 'i', 'j']
)

# %%
m1
# Out:
#    key1  key2  key3
# f     4     1     2
# g     3     2     3
# h     5     3     4
# i     6     4     5
# j     3     5     6

# %%
m2
# Out:
#    key1  key2  key3
# f     4     1     2
# g     3     0     9
# h     5     3     2
# i     6     4     5
# j     3     0     5

# %%
m1.join(m2)
# Out:
#    key1  key2  key3  key4  key5  key6
# f     4     1     2     4     1     2
# g     3     2     3     3     0     9
# h     5     3     4     5     3     2
# i     6     4     5     6     4     5
# j     3     5     6     3     0     5

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2                             Heikkinen, Miss. Laina         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# ...

# %%
df['Fare_INR'] = df['Fare'].apply(lambda x : x*80)

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2                             Heikkinen, Miss. Laina         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# ...

# %%
def euro_inr(x):
  return x*80
df['Fare_INR'] = df['Fare'].apply(euro_inr)

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2                             Heikkinen, Miss. Laina         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# ...

# %%
df['name_len'] = df['Name'].apply(len)

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2                             Heikkinen, Miss. Laina         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# ...

# %%
def cat_fare(x):
  if x<10:
    return "cheap"
  elif x>=10 and x<20:
    return "mid"
  else:
    return "high"

# %%
df['cat_fare'] = df['Fare'].apply(cat_fare)

# %%
df
# Out:
#      index                                               Name  Survived  \
# 0        0                            Braund, Mr. Owen Harris         0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2        2                             Heikkinen, Miss. Laina         1
# 3        3                           Allen, Mr. William Henry         0
# 4        4                                   Moran, Mr. James         0
# ..     ...                                                ...       ...
# 885    885                              Montvila, Rev. Juozas         0
# 886    886                       Graham, Miss. Margaret Edith         1
# 887    887           Johnston, Miss. Catherine Helen "Carrie"         0
# 888    888                              Behr, Mr. Karl Howell         1
# 889    889                                Dooley, Mr. Patrick         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# ...
